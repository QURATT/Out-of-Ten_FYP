# %%
# !pip install -q transformers

# %%
pip install --upgrade pip
# Out:
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 21.0.1
#     Uninstalling pip-21.0.1:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\programdata\\anaconda3\\lib\\site-packages\\pip\\_internal\\build_env.py'
# Consider using the `--user` option or check the permissions.

# %%
# !pip install -q youtube_transcript_api

# %%
from transformers import pipeline
from youtube_transcript_api import YouTubeTranscriptApi
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
array_of_txt=['Lenovo thinkpad X1.txt',
              'Lenovo yoga 9i gen7.txt',
              'Links HP Envy 13.txt',
              'Links HP Envy 360.txt',
              'Links HP spectre X360.txt',
              'MacBook Air M2.txt',
              'Macbook M1.txt']
              
array_of_csv2=['Lenovo-thinkpad-x.csv',
              'Lenovo-yoga-9i-gen7.csv',
              'HP-Envy-13.csv',
              'HP-Envy-360.csv',
              'lenovo-thinkpad-e14.csv',
              'MacBook-Air-M2.csv',
              'Macbook-M1.csv']
for i in range(len(array_of_txt)):
    
    with open(array_of_txt[i],'r') as file:
            Lines = file.readlines()
  
            count = 0
 
            for line in Lines:
                count += 1
                string2=line.strip()
                string1="https://www.youtube.com/watch?="
                #print(string2)
                youtube_video = string1 +string2
                #print(youtube_video)
                video_id = youtube_video.split("=")[1]
                #print(video_id)
                from IPython.display import YouTubeVideo
                YouTubeVideo(video_id)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(video_id)

# %%
YouTubeTranscriptApi.get_transcript(video_id)
transcript = YouTubeTranscriptApi.get_transcript(video_id)

# %%
transcript[0:5]
# Out:
# [{'text': 'all right so the macbook pro 13 m1 has',
#   'start': 0.08,
#   'duration': 4.48},
#  {'text': 'been my daily driver now for the past',
#   'start': 2.879,
#   'duration': 2.641},
#  {'text': 'six months', 'start': 4.56, 'duration': 2.4},
#  {'text': "and i thought i'd give you some insight",
#   'start': 5.52,
#   'duration': 3.6},
#  {'text': 'into what my experience has been like',
#   'start': 6.96,
#   'duration': 10.96}]

# %%
result = ""
for i in transcript:
    result += ' ' + i['text']
#print(result)
print(len(result))
# Out:
# 10683
